# %% [markdown]
# ### **Reading the file**

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df_loc_yearavg = pd.read_csv('Data/locationwise.csv')
df_loc_yearavg
# Out:
#     Location        Date     AQImean  AQImed  AQImin  AQImax     AQIstd  \
# 0   barishal  2014-12-31  156.877256   128.0    52.0   406.0  85.415307
# 1   barishal  2015-12-31  154.155015   119.0     0.0   402.0  90.495639
# 2   barishal  2016-12-31  131.287540    92.0    12.0   407.0  90.983940
# 3   barishal  2017-12-31  132.792899   103.5    12.0   379.0  93.769677
# 4   barishal  2018-12-31  106.384615    73.0     8.0   336.0  80.552575
# ..       ...         ...         ...     ...     ...     ...        ...
# 77    sylhet  2016-12-31   79.462633    64.0    11.0   310.0  59.721492
# 78    sylhet  2017-12-31   95.021858    76.5     8.0   328.0  67.397204
# 79    sylhet  2018-12-31  107.362637    95.5    10.0   341.0  73.316705
# 80    sylhet  2019-12-31   96.913580    83.0     9.0   262.0  63.334426
# 81    sylhet  2021-12-31  149.356757   143.0    23.0   346.0  72.348585
#
#         Date.1  Measurements
# 0   2014-02-17           277
# 1   2015-01-01           329
# ...

# %%
df_loc_yearavg['Location']
# Out:
# 0     barishal
# 1     barishal
# 2     barishal
# 3     barishal
# 4     barishal
#         ...
# 77      sylhet
# 78      sylhet
# 79      sylhet
# 80      sylhet
# 81      sylhet
# Name: Location, Length: 82, dtype: object

# %%
barishal_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('bar')]
chittagong_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('chi')]
cumilla_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('cum')]
dhaka_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('dha')]
gazipur_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('gaz')]
khulna_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('khu')]
mymensingh_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('mym')]
narayanganj_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('nar')]
narsingdi_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('nars')]
rajshahi_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('raj')]
rangpur_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('ran')]
savar_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('sav')]
sylhet_df_Yearly = df_loc_yearavg[df_loc_yearavg['Location'].str.startswith('syl')]


dhaka_df_Yearly
# Out:
#    Location        Date     AQImean  AQImed  AQImin  AQImax      AQIstd  \
# 21    dhaka  2014-12-31  160.460481   132.0    39.0   399.0   93.289396
# 22    dhaka  2015-12-31  161.855556   141.5    20.0   403.0   91.907797
# 23    dhaka  2016-12-31  146.474432   112.0     8.0   419.0  103.731955
# 24    dhaka  2017-12-31  156.568306   121.0    26.0   477.0   96.128877
# 25    dhaka  2018-12-31  190.498615   163.0    17.0   557.0  111.376916
# 26    dhaka  2019-12-31  168.707182   145.0    11.0   479.0   96.220214
# 27    dhaka  2020-12-31  151.707246   107.0    20.0   406.0  108.290488
# 28    dhaka  2021-12-31  250.470000   249.0    57.0   432.0   98.435343
# 29    dhaka  2022-12-31  229.567010   216.0    86.0   405.0   91.274415
#
#         Date.1  Measurements
# 21  2014-02-17           291
# 22  2015-01-01           360
# 23  2016-01-01           352
# 24  2017-01-01           366
# 25  2018-01-01           361
# 26  2019-01-01           362
# 27  2020-01-01           345
# ...

# %%
barishal_df_Yearly['Date'] = pd.to_datetime(barishal_df_Yearly['Date'], errors = 'coerce', )
chittagong_df_Yearly['Date'] = pd.to_datetime(chittagong_df_Yearly['Date'], errors = 'coerce', )
cumilla_df_Yearly['Date'] = pd.to_datetime(cumilla_df_Yearly['Date'], errors = 'coerce', )
dhaka_df_Yearly['Date'] = pd.to_datetime(dhaka_df_Yearly['Date'], errors = 'coerce', )
gazipur_df_Yearly['Date'] = pd.to_datetime(gazipur_df_Yearly['Date'], errors = 'coerce', )
khulna_df_Yearly['Date'] = pd.to_datetime(khulna_df_Yearly['Date'], errors = 'coerce', )
mymensingh_df_Yearly['Date'] = pd.to_datetime(mymensingh_df_Yearly['Date'], errors = 'coerce', )
narayanganj_df_Yearly['Date'] = pd.to_datetime(narayanganj_df_Yearly['Date'], errors = 'coerce', )
narsingdi_df_Yearly['Date'] = pd.to_datetime(narsingdi_df_Yearly['Date'], errors = 'coerce', )
rajshahi_df_Yearly['Date'] = pd.to_datetime(rajshahi_df_Yearly['Date'], errors = 'coerce', )
rangpur_df_Yearly['Date'] = pd.to_datetime(rangpur_df_Yearly['Date'], errors = 'coerce', )
savar_df_Yearly['Date'] = pd.to_datetime(savar_df_Yearly['Date'], errors = 'coerce', )
sylhet_df_Yearly['Date'] = pd.to_datetime(sylhet_df_Yearly['Date'], errors = 'coerce', )




dhaka_df_Yearly.info()
# Out:
# /tmp/ipykernel_493207/470815090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barishal_df_Yearly['Date'] = pd.to_datetime(barishal_df_Yearly['Date'], errors = 'coerce', )
# /tmp/ipykernel_493207/470815090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chittagong_df_Yearly['Date'] = pd.to_datetime(chittagong_df_Yearly['Date'], errors = 'coerce', )
# /tmp/ipykernel_493207/470815090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sylhet_df_Yearly
# Out:
#    Location       Date     AQImean  AQImed  AQImin  AQImax     AQIstd  \
# 75   sylhet 2014-12-31  110.909747    94.0    23.0   446.0  67.837902
# 76   sylhet 2015-12-31  117.786942    90.0     0.0   356.0  81.859358
# 77   sylhet 2016-12-31   79.462633    64.0    11.0   310.0  59.721492
# 78   sylhet 2017-12-31   95.021858    76.5     8.0   328.0  67.397204
# 79   sylhet 2018-12-31  107.362637    95.5    10.0   341.0  73.316705
# 80   sylhet 2019-12-31   96.913580    83.0     9.0   262.0  63.334426
# 81   sylhet 2021-12-31  149.356757   143.0    23.0   346.0  72.348585
#
#         Date.1  Measurements
# 75  2014-02-17           277
# 76  2015-01-01           291
# 77  2016-01-01           281
# 78  2017-01-01           366
# 79  2018-01-01           364
# 80  2019-01-01           324
# 81  2021-01-01           185

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=barishal_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=barishal_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Barishal Average AQI', fontsize = 25)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=chittagong_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=chittagong_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Chittagong Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=dhaka_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=dhaka_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Dhaka Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=cumilla_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=cumilla_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Cumilla Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=dhaka_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=dhaka_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Dhaka Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=gazipur_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=gazipur_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Gazipur Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=khulna_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=khulna_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Khulna Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=mymensingh_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=mymensingh_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Mymensingh Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=narayanganj_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=narayanganj_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Narayanganj Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=narsingdi_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=narsingdi_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Narsingdi Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=rajshahi_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=rajshahi_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Rajshahi Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=rangpur_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=rangpur_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Rangpur Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=savar_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=savar_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Savar Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(18,12))
sns.lineplot(data=sylhet_df_Yearly, x='Date', y='AQImean', palette='deep', lw=5, alpha=0.7)
sns.scatterplot(data=sylhet_df_Yearly, x='Date', y='AQImean', palette='deep', legend=False)
plt.xlim(datetime.strptime('2014-12-31', "%Y-%m-%d"), datetime.strptime('2021-12-31', "%Y-%m-%d"))

plt.title('Yearly Sylhet Average AQI', fontsize = 20)
plt.ylabel('AQI', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# ### **Before Covid Comparision (Locationwise)**
